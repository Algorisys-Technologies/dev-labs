# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
data = {
    'Employee_id': [10, 20, 15, 25, 30],
    'Gender': ['M', 'F', 'F', 'M', 'F'],
    'Remarks': ['Good', 'Nice', 'Good', 'Great', 'Nice'],
}
df = pd.DataFrame(data)
print("Employee data : ", df)
# Out:
# Employee data :     Employee_id Gender Remarks
# 0           10      M    Good
# 1           20      F    Nice
# 2           15      F    Good
# 3           25      M   Great
# 4           30      F    Nice
