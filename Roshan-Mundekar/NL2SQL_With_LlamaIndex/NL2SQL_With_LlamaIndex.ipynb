# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO, force=True)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))
from IPython.display import Markdown, display

# %%
# !pip install pymysql

# %%
# !pip install llama_index
# Out:
# Collecting llama_index
#   Downloading llama_index-0.11.23-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4 (from llama_index)
#   Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.1 (from llama_index)
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.12.0,>=0.11.23 (from llama_index)
#   Downloading llama_index_core-0.11.23-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama_index)
#   Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl.metadata (686 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama_index)
#   Downloading llama_index_indices_managed_llama_cloud-0.5.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama_index)
#   Downloading llama_index_legacy-0.9.48.post4-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.10 (from llama_index)
#   Downloading llama_index_llms_openai-0.2.16-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama_index)
#   Downloading llama_index_multi_modal_llms_openai-0.2.3-py3-none-any.whl.metadata (729 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama_index)
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama_index)
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.4.0,>=0.3.0 (from llama_index)
#   Downloading llama_index_readers_file-0.3.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama_index)
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting nltk>3.8.1 (from llama_index)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: openai>=1.14.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.56.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.10.11)
# Requirement already satisfied: dataclasses-json in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.6.7)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Using cached dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httpx in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.21.6)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (10.4.0)
# Collecting pydantic<3.0.0,>=2.7.0 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests>=2.31.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.14.1)
# Collecting llama-cloud>=0.1.5 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index)
#   Downloading llama_cloud-0.1.7-py3-none-any.whl.metadata (860 bytes)
# Requirement already satisfied: pandas in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.3.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (4.12.3)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index)
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index)
#   Using cached striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama_index)
#   Downloading llama_parse-0.5.15-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: click in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (2.5)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.2)
# Requirement already satisfied: idna in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.7)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.14.0)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from click->nltk>3.8.1->llama_index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (0.8.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Downloading pydantic_core-2.27.2-cp38-cp38-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.5.0 (from llama-index-core<0.12.0,>=0.11.23->llama_index)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from python-dateutil>=2.7.3->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.2.0)
# Downloading llama_index-0.11.23-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.11.23-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 12.1 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.5.0-py3-none-any.whl (11 kB)
# Downloading llama_index_legacy-0.9.48.post4-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.0 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.16-py3-none-any.whl (13 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.3.0-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading llama_cloud-0.1.7-py3-none-any.whl (242 kB)
# Downloading llama_parse-0.5.15-py3-none-any.whl (13 kB)
# Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp38-cp38-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 13.7 MB/s eta 0:00:00
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# Using cached striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: striprtf, filetype, dirtyjson, typing-extensions, fsspec, deprecated, pypdf, pydantic-core, nltk, annotated-types, pydantic, llama-cloud, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama_index
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.4
#     Uninstalling pydantic-1.10.4:
#       Successfully uninstalled pydantic-1.10.4
# Successfully installed annotated-types-0.7.0 deprecated-1.2.15 dirtyjson-1.0.8 filetype-1.2.0 fsspec-2024.12.0 llama-cloud-0.1.7 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-core-0.11.23 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.5.0 llama-index-legacy-0.9.48.post4 llama-index-llms-openai-0.2.16 llama-index-multi-modal-llms-openai-0.2.3 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.3.0 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.15 llama_index-0.11.23 nltk-3.9.1 pydantic-2.10.4 pydantic-core-2.27.2 pypdf-5.1.0 striprtf-0.0.26 typing-extensions-4.12.2

# %%
# pip install --force-reinstall 'sqlalchemy<2.0.0'

# %%
import pymysql

# %% [markdown]
# ## Connect to Database

# %%
db_user = "root"
db_password = "root"
db_host = "localhost"
db_name = "classicmodels"

# %%
from sqlalchemy import create_engine, text

# Construct the connection string
connection_string = f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}?charset=utf8"

# Create an engine instance
engine = create_engine(connection_string)

# Test the connection using raw SQL
with engine.connect() as connection:
    result = connection.execute(text("show tables"))
    for row in result:
        print(row)
# Out:
# ('customers',)
# ('employees',)
# ('offices',)
# ('orderdetails',)
# ('orders',)
# ('payments',)
# ('productlines',)
# ('products',)

# %% [markdown]
# ## Load database to llamaIndex SQLDatabase

# %%
# !pip uninstall llama_index
# !pip install llama_index
# !pip install llama_index==0.5.0

# %%
from llama_index.core import SQLDatabase

# %%
tables = ['customers', 'employees', 'offices', 'orderdetails', 'orders', 'payments', 'productlines', 'products']
sql_database = SQLDatabase(engine, include_tables=tables, sample_rows_in_table_info=2)
sql_database

# %%
sql_database._all_tables
# Out:
# {'customers',
#  'employees',
#  'offices',
#  'orderdetails',
#  'orders',
#  'payments',
#  'productlines',
#  'products'}

# %%
sql_database.get_single_table_info
# Out:
# <bound method SQLDatabase.get_single_table_info of <llama_index.core.utilities.sql_wrapper.SQLDatabase object at 0x0000025D59E22CD0>>

# %% [markdown]
# ## Connect to OpenAI account

# %%
import os
import openai

# %%
openai.api_key = "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"

# %%
# !pip install setuptools cython
# !pip install aimrocks
# !pip install llama-index-callbacks-aim
# !pip install --upgrade pip setuptools wheel
# !pip install llama-index-callbacks-aim --no-deps
# !pip install aimrocks
# !pip install other-required-packages
# !pip install --upgrade llama-index
# !pip install --upgrade llama-index

# !pip install llama-index==0.6.0

# %%
# # !pip show llama_index

# !pip install llama_index==0.5.0
# !pip install langchain_community

# !pip install --upgrade llama_index
# !pip install --upgrade llama_index
# !pip install llama_index==0.5.16
# !pip install llama_index[langchain]
# !pip install llama_index==0.5.0
# !pip install --upgrade langchain
# !pip install llama-index llama-index-llms-ollama
# !pip install --upgrade langchain
# Out:
# Collecting llama_index==0.5.0
#   Using cached llama_index-0.5.0.tar.gz (158 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: dataclasses_json in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (0.6.7)
# Requirement already satisfied: langchain in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (0.2.17)
# Requirement already satisfied: numpy in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (1.21.6)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (8.5.0)
# Requirement already satisfied: openai>=0.26.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (1.56.1)
# Requirement already satisfied: pandas in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.0) (1.3.3)
# Collecting transformers (from llama_index==0.5.0)
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (2.10.4)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama_index==0.5.0) (4.12.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses_json->llama_index==0.5.0) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses_json->llama_index==0.5.0) (0.9.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (3.10.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (0.1.147)
# Requirement already satisfied: requests<3,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama_index==0.5.0) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama_index==0.5.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama_index==0.5.0) (2024.1)
# Collecting filelock (from transformers->llama_index==0.5.0)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers->llama_index==0.5.0)
#   Using cached huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama_index==0.5.0) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama_index==0.5.0) (2024.11.6)
# Collecting tokenizers<0.21,>=0.20 (from transformers->llama_index==0.5.0)
#   Downloading tokenizers-0.20.3-cp38-none-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers->llama_index==0.5.0)
#   Using cached safetensors-0.4.5-cp38-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (1.15.2)
# Requirement already satisfied: idna>=2.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama_index==0.5.0) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama_index==0.5.0) (1.2.0)
# Requirement already satisfied: certifi in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.26.4->llama_index==0.5.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.26.4->llama_index==0.5.0) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.26.4->llama_index==0.5.0) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers->llama_index==0.5.0) (2024.12.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain->llama_index==0.5.0) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->llama_index==0.5.0) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->llama_index==0.5.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1.9.0->openai>=0.26.4->llama_index==0.5.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1.9.0->openai>=0.26.4->llama_index==0.5.0) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from python-dateutil>=2.7.3->pandas->llama_index==0.5.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain->llama_index==0.5.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain->llama_index==0.5.0) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->llama_index==0.5.0) (3.1.1)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from tqdm>4->openai>=0.26.4->llama_index==0.5.0) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses_json->llama_index==0.5.0) (1.0.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain->llama_index==0.5.0) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain->llama_index==0.5.0) (0.2.0)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.0 MB 6.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.0 MB 9.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/10.0 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 11.2 MB/s eta 0:00:00
# Using cached huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Using cached safetensors-0.4.5-cp38-none-win_amd64.whl (286 kB)
# Downloading tokenizers-0.20.3-cp38-none-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 17.0 MB/s eta 0:00:00
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: llama_index
#   Building wheel for llama_index (setup.py): started
#   Building wheel for llama_index (setup.py): finished with status 'done'
#   Created wheel for llama_index: filename=llama_index-0.5.0-py3-none-any.whl size=239215 sha256=6ebc251c9391f6174118cc722429358de700c8c01bc03c53e0be2a6f53fa6966
#   Stored in directory: c:\users\roshan\appdata\local\pip\cache\wheels\33\c6\d1\4ca139ea606f4aa82e38f30800df801f28c186bab876297a8b
# Successfully built llama_index
# Installing collected packages: safetensors, filelock, huggingface-hub, tokenizers, transformers, llama_index
#   Attempting uninstall: llama_index
#     Found existing installation: llama-index 0.11.23
#     Uninstalling llama-index-0.11.23:
#       Successfully uninstalled llama-index-0.11.23
# Successfully installed filelock-3.16.1 huggingface-hub-0.27.0 llama_index-0.5.0 safetensors-0.4.5 tokenizers-0.20.3 transformers-4.46.3
# Requirement already satisfied: langchain_community in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (0.2.19)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (3.10.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (0.2.17)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (1.21.6)
# Requirement already satisfied: requests<3,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain<0.3.0,>=0.2.17->langchain_community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain<0.3.0,>=0.2.17->langchain_community) (2.10.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain_community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.2.0)
# Requirement already satisfied: llama_index in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (0.5.0)
# Collecting llama_index
#   Using cached llama_index-0.11.23-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.23 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.11.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.5.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.4.0,>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.56.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.10.11)
# Requirement already satisfied: dataclasses-json in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.21.6)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (0.1.7)
# Requirement already satisfied: pandas in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.3.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama_index) (0.5.15)
# Requirement already satisfied: click in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (2.5)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.2)
# Requirement already satisfied: idna in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.7)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.14.0)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from click->nltk>3.8.1->llama_index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (0.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from python-dateutil>=2.7.3->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.2.0)
# Using cached llama_index-0.11.23-py3-none-any.whl (6.8 kB)
# Installing collected packages: llama_index
#   Attempting uninstall: llama_index
#     Found existing installation: llama_index 0.5.0
#     Uninstalling llama_index-0.5.0:
#       Successfully uninstalled llama_index-0.5.0
# Successfully installed llama_index-0.11.23
# Requirement already satisfied: llama_index in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (0.11.23)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.23 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.11.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.5.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.4.0,>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.56.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.10.11)
# Requirement already satisfied: dataclasses-json in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.21.6)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama_index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (0.1.7)
# Requirement already satisfied: pandas in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.3.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama_index) (0.5.15)
# Requirement already satisfied: click in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama_index) (2.5)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (2024.8.30)
# Requirement already satisfied: anyio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.2)
# Requirement already satisfied: idna in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.7)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.14.0)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from click->nltk>3.8.1->llama_index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama_index) (0.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.23->llama_index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama_index) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from python-dateutil>=2.7.3->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama_index) (0.2.0)
# Collecting llama_index==0.5.16
#   Using cached llama_index-0.5.16.tar.gz (175 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: dataclasses_json in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (0.6.7)
# Requirement already satisfied: langchain>=0.0.123 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (0.2.17)
# Requirement already satisfied: numpy in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (1.21.6)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (8.5.0)
# Requirement already satisfied: openai>=0.26.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (1.56.1)
# Requirement already satisfied: pandas in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (1.3.3)
# Requirement already satisfied: transformers in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama_index==0.5.16) (4.46.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain>=0.0.123->llama_index==0.5.16) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain>=0.0.123->llama_index==0.5.16) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain>=0.0.123->llama_index==0.5.16) (3.10.11)
# ...
# Requirement already satisfied: networkx>=3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama-index) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama-index) (0.8.0)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from openai>=0.26.4->llama-index) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from dataclasses-json->llama-index) (3.22.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama-index) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama-index) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama-index) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain->llama-index) (0.1.147)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pandas->llama-index) (2024.1)
# Requirement already satisfied: filelock in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (0.27.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (2024.11.6)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from transformers->llama-index) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.15.2)
# Requirement already satisfied: idna>=2.8 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama-index) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama-index) (1.2.0)
# Requirement already satisfied: certifi in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain->llama-index) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->llama-index) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->llama-index) (1.0.0)
# Requirement already satisfied: click in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from python-dateutil>=2.7.3->pandas->llama-index) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (3.1.1)
# Requirement already satisfied: colorama in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain->llama-index) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-ollama) (0.2.0)
# Downloading llama_index_llms_ollama-0.3.6-py3-none-any.whl (5.9 kB)
# Downloading ollama-0.4.5-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, llama-index-llms-ollama
# Successfully installed llama-index-llms-ollama-0.3.6 ollama-0.4.5
# Requirement already satisfied: langchain in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (0.2.17)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (3.10.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (1.21.6)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.15.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from pydantic<3,>=1->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\roshan\anaconda3\envs\projectpy\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)

# %% [markdown]
# ## Connect to LLM and initialize the service context

# %%
import tiktoken
from llama_index.core.callbacks import CallbackManager, TokenCountingHandler
token_counter = TokenCountingHandler(
    tokenizer=tiktoken.encoding_for_model("gpt-3.5-turbo").encode
)

callback_manager = CallbackManager([token_counter])

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings

Settings.llm = OpenAI(model="gpt-3.5-turbo")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
Settings.node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=20)
Settings.num_output = 512
Settings.context_window = 3900

# %% [markdown]
# ## Create SQL table node mapping

# %%
#creating SQL table node mapping
from llama_index.core import VectorStoreIndex
from llama_index.core.objects import ObjectIndex, SQLTableNodeMapping, SQLTableSchema
import pandas as pd

# list all the tables from database and crate table schema for prompt to LLM
tables = list(sql_database._all_tables)
table_node_mapping = SQLTableNodeMapping(sql_database)
table_schema_objs = []
for table in tables:
    table_schema_objs.append((SQLTableSchema(table_name = table)))

# %%
print(table_schema_objs)
# Out:
# [SQLTableSchema(table_name='customers', context_str=None), SQLTableSchema(table_name='payments', context_str=None), SQLTableSchema(table_name='productlines', context_str=None), SQLTableSchema(table_name='orderdetails', context_str=None), SQLTableSchema(table_name='orders', context_str=None), SQLTableSchema(table_name='products', context_str=None), SQLTableSchema(table_name='employees', context_str=None), SQLTableSchema(table_name='offices', context_str=None)]

# %% [markdown]
# ## Initialize SQL Table Retrieval Engine

# %%
from llama_index.core.indices.struct_store.sql_query import SQLTableRetrieverQueryEngine

obj_index = ObjectIndex.from_objects(
    table_schema_objs,
    table_node_mapping,
    VectorStoreIndex
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
# Create the query engine
query_engine = SQLTableRetrieverQueryEngine(
    sql_database, obj_index.as_retriever(similarity_top_k=3), service_context=Settings
)

# %%
response = query_engine.query("How many tables inclassimodels  database?")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:llama_index.core.indices.struct_store.sql_retriever:> Table desc str: Table 'customers' has columns: customerNumber (INTEGER), customerName (VARCHAR(50)), contactLastName (VARCHAR(50)), contactFirstName (VARCHAR(50)), phone (VARCHAR(50)), addressLine1 (VARCHAR(50)), addressLine2 (VARCHAR(50)), city (VARCHAR(50)), state (VARCHAR(50)), postalCode (VARCHAR(15)), country (VARCHAR(50)), salesRepEmployeeNumber (INTEGER), creditLimit (DECIMAL(10, 2)),  and foreign keys: ['salesRepEmployeeNumber'] -> employees.['employeeNumber'].
#
# Table 'orders' has columns: orderNumber (INTEGER), orderDate (DATE), requiredDate (DATE), shippedDate (DATE), status (VARCHAR(15)), comments (TEXT), customerNumber (INTEGER),  and foreign keys: ['customerNumber'] -> customers.['customerNumber'].
#
# Table 'employees' has columns: employeeNumber (INTEGER), lastName (VARCHAR(50)), firstName (VARCHAR(50)), extension (VARCHAR(10)), email (VARCHAR(100)), officeCode (VARCHAR(10)), reportsTo (INTEGER), jobTitle (VARCHAR(50)),  and foreign keys: ['reportsTo'] -> employees.['employeeNumber'], ['officeCode'] -> offices.['officeCode'].
# > Table desc str: Table 'customers' has columns: customerNumber (INTEGER), customerName (VARCHAR(50)), contactLastName (VARCHAR(50)), contactFirstName (VARCHAR(50)), phone (VARCHAR(50)), addressLine1 (VARCHAR(50)), addressLine2 (VARCHAR(50)), city (VARCHAR(50)), state (VARCHAR(50)), postalCode (VARCHAR(15)), country (VARCHAR(50)), salesRepEmployeeNumber (INTEGER), creditLimit (DECIMAL(10, 2)),  and foreign keys: ['salesRepEmployeeNumber'] -> employees.['employeeNumber'].
#
# Table 'orders' has columns: orderNumber (INTEGER), orderDate (DATE), requiredDate (DATE), shippedDate (DATE), status (VARCHAR(15)), comments (TEXT), customerNumber (INTEGER),  and foreign keys: ['customerNumber'] -> customers.['customerNumber'].
#
# Table 'employees' has columns: employeeNumber (INTEGER), lastName (VARCHAR(50)), firstName (VARCHAR(50)), extension (VARCHAR(10)), email (VARCHAR(100)), officeCode (VARCHAR(10)), reportsTo (INTEGER), jobTitle (VARCHAR(50)),  and foreign keys: ['reportsTo'] -> employees.['employeeNumber'], ['officeCode'] -> offices.['officeCode'].
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print(response)
# Out:
# There are 0 tables in the inclassmodels database.

# %%
from llama_index.core import VectorStoreIndex
from llama_index.llms.openai import OpenAI
from sqlalchemy import create_engine, text

# Initialize GPT-3.5 model
gpt35_llm = OpenAI(model="gpt-3.5-turbo")

# Assuming `index` is already created and populated
query_str = "How many employees do we have?"

# Retrieve vectors from index to get most relevant examples
query_engine = index.as_query_engine(similarity_top_k=2, llm=gpt35_llm)

# Get the response prompt (which is a SQL query)
response_prompt = query_engine.query(query_str)
print(f"Generated SQL Query: {response_prompt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 12
#       9 query_str = "How many employees do we have?"
#      11 # Retrieve vectors from index to get most relevant examples
# ---> 12 query_engine = index.as_query_engine(similarity_top_k=2, llm=gpt35_llm)
#      14 # Get the response prompt (which is a SQL query)
#      15 response_prompt = query_engine.query(query_str)
#
# NameError: name 'index' is not defined

# %%
# import openai
# import pandas as pd
# from sqlalchemy import create_engine, text
# from llama_index.core import VectorStoreIndex
# from llama_index.llms.openai import OpenAI
# from llama_index.core import Settings
# from llama_index.core.indices.struct_store.sql_query import SQLTableRetrieverQueryEngine
# from llama_index.core.objects import ObjectIndex, SQLTableNodeMapping, SQLTableSchema
# from llama_index.embeddings.openai import OpenAIEmbedding
# from llama_index.core.node_parser import SentenceSplitter

# # Set your OpenAI API key
# openai.api_key = "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" # Replace with your actual OpenAI API key

# # Database connection details
# db_user = "root"
# db_password = "root"
# db_host = "localhost"
# db_name = "classicmodels"

# # Create SQLAlchemy engine
# connection_string = f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}?charset=utf8"
# engine = create_engine(connection_string)

# # Create SQLDatabase object
# sql_database = SQLDatabase(engine)

# # List all tables in the database
# tables = sql_database._all_tables

# # Create SQL table schema descriptions
# table_schema_objs = []
# for table in tables:
#     table_schema_objs.append(SQLTableSchema(table_name=table))

# # Initialize ObjectIndex and SQLTableNodeMapping
# table_node_mapping = SQLTableNodeMapping(sql_database)
# obj_index = ObjectIndex.from_objects(table_schema_objs, table_node_mapping, VectorStoreIndex)

# # Initialize the OpenAI model for query generation
# Settings.llm = OpenAI(model="gpt-3.5-turbo")  # Set model to use
# Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
# Settings.node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=20)
# Settings.num_output = 512
# Settings.context_window = 3900

# # Initialize SQL Table Retrieval Engine
# query_engine = SQLTableRetrieverQueryEngine(
#     sql_database, obj_index.as_retriever(similarity_top_k=3), service_context=Settings
# )

# # Example query: "How many employees do we have?"
# query_str = "The query retrieves the names of customers who have not made any payments.?"

# # Generate SQL query using LlamaIndex's query engine
# def generate_sql_query(query_str):
#     # Query the engine to generate SQL from natural language
#     response = query_engine.query(query_str)
    
#     # Return the generated SQL query as a string
#     return str(response).strip()

# # Generate the SQL query
# generated_sql_query = generate_sql_query(query_str)
# print(f"Generated SQL Query: {generated_sql_query}")

# %%
import openai
import pandas as pd
from sqlalchemy import create_engine, text
from llama_index.core import VectorStoreIndex
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings
from llama_index.core.indices.struct_store.sql_query import SQLTableRetrieverQueryEngine
from llama_index.core.objects import ObjectIndex, SQLTableNodeMapping, SQLTableSchema
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter


# Set your OpenAI API key
openai.api_key = "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"  # Replace with your actual OpenAI API key


# Database connection details
db_user = "root"
db_password = "root"
db_host = "localhost"
db_name = "classicmodels"

# Create SQLAlchemy engine
connection_string = f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}?charset=utf8"
engine = create_engine(connection_string)

# Create SQLDatabase object
from llama_index.core import SQLDatabase
sql_database = SQLDatabase(engine)

# List all tables in the database
tables = sql_database._all_tables

# Create SQL table schema descriptions
table_schema_objs = []
for table in tables:
    table_schema_objs.append(SQLTableSchema(table_name=table))

# Initialize ObjectIndex and SQLTableNodeMapping
table_node_mapping = SQLTableNodeMapping(sql_database)
obj_index = ObjectIndex.from_objects(table_schema_objs, table_node_mapping, VectorStoreIndex)

# Define the SQL query generation function
def generate_sql_query(query_str):
    """
    Given a natural language question, generate the correct SQL query for the database.
    This uses LlamaIndex's query engine to generate the SQL query from the input question.
    """
    # Define the prompt for the model with a clear instruction to only generate SQL query
    prompt = f"""
    You are an agent designed to interact with a SQL database. 
    Given the following question, generate only the correct SQL query to retrieve the requested information.
    
    Question: {query_str}
    SQL Query (only the query, no explanations or additional text):
    """

    # Initialize the OpenAI model for query generation
    Settings.llm = OpenAI(model="gpt-3.5-turbo")  # Set model to use

    # Initialize SQL Table Retrieval Engine
    query_engine = SQLTableRetrieverQueryEngine(
        sql_database, obj_index.as_retriever(similarity_top_k=3), service_context=Settings
    )

    # Query the engine to generate a SQL query based on the prompt
    sql_query_response = query_engine.query(prompt)

    # Check if the response has a 'text' attribute and extract the query
    if hasattr(sql_query_response, 'text'):
        sql_query = sql_query_response.text.strip()  # Extract the SQL query text and remove extra spaces
    else:
        # If the response does not have a 'text' attribute, fall back to using str() for extraction
        sql_query = str(sql_query_response).strip()

    # Return the clean SQL query
    return sql_query

# Example natural language query (question)
query_str = "How many employees do we have?"

# Generate the SQL query using the question
generated_sql_query = generate_sql_query(query_str)

# Print the generated SQL query
print(f"Generated SQL Query: {generated_sql_query}")

# Execute the generated SQL query using SQLAlchemy
try:
    with engine.connect() as connection:
        result = connection.execute(text(generated_sql_query))  # Execute SQL query
        df = pd.DataFrame(result.fetchall(), columns=result.keys())  # Convert to DataFrame
        print(df)  # Display the results in a DataFrame
except Exception as e:
    print(f"Error executing SQL: {e}")
# Out:
# Generated SQL Query: There are 23 employees in the database.
# Error executing SQL: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'There are 23 employees in the database.' at line 1")
# [SQL: There are 23 employees in the database.]
# (Background on this error at: https://sqlalche.me/e/20/f405)
